# %%
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv('train.csv')
dataset
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
dataset.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
wkDataset = dataset.copy()
wkDataset
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
wkDataset['Embarked'].fillna(wkDataset['Embarked'].mode()[0],inplace=True)
wkDataset['Age'].fillna(wkDataset['Age'].mean(),inplace=True)
wkDataset.isna().sum()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12524\664059274.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   wkDataset['Embarked'].fillna(wkDataset['Embarked'].mode()[0],inplace=True)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12524\664059274.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
dummies = pd.get_dummies(wkDataset['Embarked'])
dummies = dummies.astype(int)
dummies.head()

wkDataset = pd.concat([wkDataset,dummies],axis=1)
wkDataset.head()

input = wkDataset.drop('Embarked',axis=1)
input.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin  C  Q  S
# 0      0         A/5 21171   7.2500   NaN  0  0  1
# 1      0          PC 17599  71.2833   C85  1  0  0
# 2      0  STON/O2. 3101282   7.9250   NaN  0  0  1
# 3      0            113803  53.1000  C123  0  0  1
# 4      0            373450   8.0500   NaN  0  0  1

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

wkDataset['Embarked_le'] = le.fit_transform(wkDataset['Embarked'])
wkDataset.head(10)

input = wkDataset.drop('Embarked',axis=1)
input.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin  C  Q  S  Embarked_le
# 0      0         A/5 21171   7.2500   NaN  0  0  1            2
# 1      0          PC 17599  71.2833   C85  1  0  0            0
# 2      0  STON/O2. 3101282   7.9250   NaN  0  0  1            2
# ...

# %%
embarked_mapping = {'S':0,'C':1,'Q':2}
wkDataset['Embarked'] = wkDataset['Embarked'].map(embarked_mapping)
wkDataset
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
sex_mapping = {'male':0,'female':1}
wkDataset['Sex'] = wkDataset['Sex'].map(sex_mapping)
wkDataset
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex        Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    0  22.000000      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.000000      1
# 2                               Heikkinen, Miss. Laina    1  26.000000      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.000000      1
# 4                             Allen, Mr. William Henry    0  35.000000      0
# ...

# %%
wkDataset.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# C                0
# Q                0
# S                0
# Embarked_le      0
# dtype: int64

# %% [markdown]
# One Hot encoding

# %%
ecDataset = dataset.copy()

# %%
one_hot_encoded = pd.get_dummies(ecDataset['Embarked'],prefix='Embarked_onehot')
ecDataset = pd.concat([ecDataset,one_hot_encoded],axis=1)
ecDataset
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
ecDataset['Embarked_onehot_C'] = ecDataset['Embarked_onehot_C'].astype(int)
ecDataset['Embarked_onehot_Q'] = ecDataset['Embarked_onehot_Q'].astype(int)
ecDataset['Embarked_onehot_S'] = ecDataset['Embarked_onehot_S'].astype(int)

ecDataset
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Count the total number of survived passengers
total_survived = len(ecDataset[ecDataset['Survived'] == 1])

print("Total number of passengers who survived:", total_survived)
# Out:
# Total number of passengers who survived: 342

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

sns.countplot(x='Sex',data=dataset,palette='pastel')
plt.xlabel('Sex')
plt.ylabel('Count')
plt.title('Distribution of Sex')
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12524\777190205.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Sex',data=dataset,palette='pastel')

# %%
sns.boxplot(x='Pclass', y='Age', data=dataset, palette='pastel')
plt.xlabel('Pclass')
plt.ylabel('Age')
plt.title('Box Plot of Age across Pclass')
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12524\1263988713.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Pclass', y='Age', data=dataset, palette='pastel')

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()\

dataset['Sex'] = le.fit_transform(dataset['Sex'])
dataset.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
df1 = dataset[['Fare','Age','Survived','Sex']]
corr = df1.corr()

sns.heatmap(corr,annot=True)
plt.show()

# %%
dummies = pd.get_dummies(dataset['Embarked'],prefix='Em')
dummies = dummies.astype(int)
dummies.head()
# Out:
#    Em_C  Em_Q  Em_S
# 0     0     0     1
# 1     1     0     0
# 2     0     0     1
# 3     0     0     1
# 4     0     0     1

# %%
dataset = pd.concat([dataset,dummies],axis=1)
dataset.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  Em_C  Em_Q  Em_S
# 0         A/5 21171   7.2500   NaN        S     0     0     1
# 1          PC 17599  71.2833   C85        C     1     0     0
# 2  STON/O2. 3101282   7.9250   NaN        S     0     0     1
# ...

# %%
dataset = dataset.drop('Embarked',axis=1)
dataset.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Cabin  Em_C  Em_Q  Em_S
# 0         A/5 21171   7.2500   NaN     0     0     1
# 1          PC 17599  71.2833   C85     1     0     0
# 2  STON/O2. 3101282   7.9250   NaN     0     0     1
# 3            113803  53.1000  C123     0     0     1
# ...

# %%
sns.boxplot(x='Pclass',y='Age',data=dataset)
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>
